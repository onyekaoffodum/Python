# %%
# Import libraries 

from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib

# %%
# Connect to Website

URL = 'https://www.jumia.com.ng/catalog/?q=handbags+for+ladies'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 Edg/121.0.0.0", "Accept-Encoding":"gzip, deflate, br", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
# Pulling in data

page = requests.get (URL, headers= headers)

Soup1 = BeautifulSoup (page.content, 'html.parser')

Soup2 = BeautifulSoup (Soup1.prettify(), 'html.parser')

name = Soup2.find(class_= 'name')

price = Soup2.find(class_= 'prc')

print(price)

print(name)
# Out:
# <div class="prc">
#             ₦ 4,190
#            </div>
# <h3 class="name">
#             Women's Underarm Large Capacity Daisy Print Ladies Bags
#            </h3>

# %%
# Iterate for the list of prices

price_elements = Soup2.find_all(class_='prc')

for price_element in price_elements:
    price = price_element.get_text().strip()[2:] # removing the first two characters
    print(price)

# %%
# Iterate for the list of names

name_elements = Soup2.find_all(class_='name')

for name_element in name_elements:
    name = name_element.get_text().strip()
    print(name)

# %%
# Create csv and type headers and data into the file

import csv

header = ['Name', 'Price']

# List of name_elements and price_elements
name_elements = Soup2.find_all(class_='name')
price_elements = Soup2.find_all(class_='prc')

# Now we are importing data into the csv
with open('JumiaWebScraperDatasetPart2.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)

    # Zip the name_elements and price_elements together for iteration
    for name_element, price_element in zip(name_elements, price_elements):
        name = name_element.get_text().strip()
        price = price_element.get_text().strip()[2:]  
        writer.writerow([name, price])

# %%
# Reading the scraped data here

import pandas as pd

df = pd.read_csv(r"C:\Users\HP\JumiaWebScraperDatasetPart2.csv")
df
# Out:
#                                                  Name   Price
# 0   Women's Underarm Large Capacity Daisy Print La...   4,190
# 1   4 PCS Women Bags Ladies Bags Handbags Purse Sh...  10,490
# 2     Ladies Elegant Multifunction Crossbody/Hand Bag  15,500
# 3   Leather Handbags Women Bags Cross-body Bags Bi...  14,000
# 4   Quality Chainy Quality Ladies Handbag- Slvr & Blk  10,999
# 5   3 PCS Women Bags Ladies Bags Handbags Purse Sh...  12,990
# 6   Women Quality Leather Hand Bag Ladies Shoulder...  11,542
# 7       LADIES UNIQUE MINI SHOULDER / HANDBAG - Black   6,500
# 8   4 PCS Women Bags Ladies Bags Handbags Purse Sh...   9,190
# 9   All Season's Leather Office Ladies Handbag 3pc...  19,900
# 10  Ladies Canvas Tote Bag Cotton Cloth Shoulder S...   4,990
# 11  Women Bags Ladies Bags Handbags Purse Shoulder...  18,090
# 12        Women Ladies Elegant Female Handbag - Black   6,500
# 13  Women Bags Handbags Ladies Bags Tote Bags Purs...   6,690
# ...
